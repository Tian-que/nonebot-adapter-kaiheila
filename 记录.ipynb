# %% [markdown]
# - Event
#   - 消息事件    MessageEvent
#     - 私聊消息  PrivateMessageEvent
#     - 频道消息  GroupMessageEvent
#         - 文字消息  type =  int
#         - 图片消息
#         - 视频消息
#         - 文件消息
#         - KMarkdown 消息
#         - Card 消息
#   - 通知事件    NoticeEvent
#     - 私聊消息事件    PrivateMessageEvent
#         - 私聊消息更新              updated_private_message
#         - 私聊消息被删除            deleted_private_message
#         - 私聊内用户添加 reaction   private_added_reaction
#         - 私聊内用户取消 reaction   private_deleted_reaction
#     - 频道事件    Channel_Event
#         - 频道用户添加reaction 事件 added_reaction
#         - 频道内用户取消 reaction   deleted_reaction
#         - 频道消息更新              updated_message
#         - 频道消息被删除            deleted_message
#         - 新增频道                  added_channel
#         - 修改频道信息              updated_channel
#         - 删除频道                  deleted_channel
#         - 新的频道置顶消息          pinned_message
#         - 取消频道置顶消息          unpinned_message
#     - 服务器事件  GuildEvent
#         - 服务器成员事件
#         - 新成员加入服务器        joined_guild
#         - 服务器成员退出          exited_guild
#         - 服务器成员信息更新      updated_guild_member
#         - 服务器成员上线          guild_member_online
#         - 服务器成员下线          guild_member_offline
#         - 服务器角色事件
#         - 服务器角色增加          added_role
#         - 服务器角色删除          deleted_role
#         - 服务器角色更新          updated_role
#         - 服务器相关事件
#         - 服务器信息更新          updated_guild
#         - 服务器删除              deleted_guild
#         - 服务器封禁用户          added_block_list
#         - 服务器取消封禁用户      deleted_block_list
#         - 用户事件
#         - 用户加入语音频道        joined_channel
#         - 用户退出语音频道        exited_channel
#         - 用户信息更新            user_updated
#             - 仅当用户的 用户名 或 头像 变更时;
#             - 仅通知与该用户存在关联的用户或 Bot:
#             - a. 存在聊天会话
#             - b. 双方好友关系
#         - 自己新加入服务器        self_joined_guild
#         - 自己退出服务器          self_exited_guild
#         - Card 消息中的 Button 点击事件
